# %% [markdown]
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-01.png">
#
# <p style="display: flex; justify-content: space-between;">
#   <a href="../README.md" target="_blank">Home</a>
#   <a href="../02-Understanding-Rebound/01-Two-Body-Simulation-using-Rebound.ipynb" target="_blank">Next</a>
# </p>
#
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-07.png">

# %% [markdown]
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-08.png">
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-09.png">

# %%
#returning the python version
# !python --version

# if using Python IDE, we cn check the version as
# import sys
# print("Python-Version:", sys.version)
# Out:
# Python 3.14.0

# %% [markdown]
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-02.png">

# %%
# Installation of NumPy in Python
# pip install numpy (using terminal for python interface)
# !pip install numpy (for jupyter notebook interface)

import numpy #importing the Package - NumPy
print("Python-NumPy-Version:", numpy.__version__)
# Out:
# Python-NumPy-Version: 2.4.2

# %%
# Installation of matplotlib in Python
# pip install matplotlib (using terminal for python interface)
# !pip install matplotlib (for jupyter notebook interface)

import matplotlib #importing the Package - Matplotlib
print("Python-Matplotlib-Version:", matplotlib.__version__)
# Out:
# Python-Matplotlib-Version: 3.10.8

# %%
# Installation of Pandas in Python
# pip install pandas (using terminal for python interface)
# !pip install pandas (for jupyter notebook interface)

import pandas #importing the Package - Pandas
print("Python-Pandas-Version", pandas.__version__)
# Out:
# Python-Pandas-Version 3.0.1

# %% [markdown]
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-03.png">
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-04.png">

# %%
# Installation of Rebound in Python
# pip install rebound (using terminal for python interface)
# !pip install rebound (for jupyter notebook interface)

# check the version of the Rebound installed
import rebound # importing the module - rebound
print("Rebound-Version:", rebound.__version__) # checking the installed version
# Out:
# Rebound-Version: 4.6.0

# %% [markdown]
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-05.png">
# <img src="../Decorative-Elements/Section-01/ADL-S01-Image-06.png">

# %%
# Installation of Plotly in Python
# pip install plotly (using terminal for python interface)
# !pip install plotly (for jupyter notebook interface)

# %%
# check the version of the Plotly installed
import plotly # importing the module - rebound
print("Version:", plotly.__version__) # checking the installed version
# Out:
# Version: 6.5.2

# %% [markdown]
# <p style="display: flex; justify-content: space-between;">
#   <a href="../README.md" target="_blank">README.md</a>
#   <a href="../02-Understanding-Rebound/01-Two-Body-Simulation-using-Rebound.ipynb" target="_blank">Next</a>
# </p>
#
# <img src="../Decorative-Elements/Section-Footer-Animated/Section-01.gif">
